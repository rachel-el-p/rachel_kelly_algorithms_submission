# %%
import pandas as pd

# %% [markdown]
# # Poverty table

# %%
# read the csv file in /census_data_by_tract

poverty_df = pd.read_csv("./census_data_by_tract/acs2021_5yr_B17001_14000US36047030600/acs2021_5yr_B17001_14000US36047030600.csv")

# %%
poverty_df
# Out:
#                    geoid                               name  B17001001  \
# 0     14000US36005000100          Census Tract 1, Bronx, NY          0
# 1     14000US36005000200          Census Tract 2, Bronx, NY       4453
# 2     14000US36005000400          Census Tract 4, Bronx, NY       6000
# 3     14000US36005001600         Census Tract 16, Bronx, NY       5826
# 4     14000US36005001901      Census Tract 19.01, Bronx, NY       2164
# ...                  ...                                ...        ...
# 2322  14000US36085030302  Census Tract 303.02, Richmond, NY       6638
# 2323  14000US36085031901  Census Tract 319.01, Richmond, NY       3386
# 2324  14000US36085031902  Census Tract 319.02, Richmond, NY       5275
# 2325  14000US36085032300     Census Tract 323, Richmond, NY       1105
# 2326  14000US36085990100    Census Tract 9901, Richmond, NY          0
#
#       B17001001, Error  B17001002  B17001002, Error  B17001003  \
# ...

# %%
# keep the first 4 columns

poverty_df = poverty_df.iloc[:, 0:4]

# %%
poverty_df
# Out:
#                    geoid                               name  B17001001  \
# 0     14000US36005000100          Census Tract 1, Bronx, NY          0
# 1     14000US36005000200          Census Tract 2, Bronx, NY       4453
# 2     14000US36005000400          Census Tract 4, Bronx, NY       6000
# 3     14000US36005001600         Census Tract 16, Bronx, NY       5826
# 4     14000US36005001901      Census Tract 19.01, Bronx, NY       2164
# ...                  ...                                ...        ...
# 2322  14000US36085030302  Census Tract 303.02, Richmond, NY       6638
# 2323  14000US36085031901  Census Tract 319.01, Richmond, NY       3386
# 2324  14000US36085031902  Census Tract 319.02, Richmond, NY       5275
# 2325  14000US36085032300     Census Tract 323, Richmond, NY       1105
# 2326  14000US36085990100    Census Tract 9901, Richmond, NY          0
#
#       B17001001, Error
# 0                   18
# 1                  563
# 2                  903
# ...

# %% [markdown]
# B17001001 is "Income in the past 12 months below poverty level:",

# %% [markdown]
# # Population Table

# %%
population_df = pd.read_csv("./census_data_by_tract/acs2021_5yr_B01003_14000US36047030600/acs2021_5yr_B01003_14000US36047030600.csv")

# %%
population_df
# Out:
#                    geoid                               name  B01003001  \
# 0     14000US36005000100          Census Tract 1, Bronx, NY       6661
# 1     14000US36005000200          Census Tract 2, Bronx, NY       4453
# 2     14000US36005000400          Census Tract 4, Bronx, NY       6000
# 3     14000US36005001600         Census Tract 16, Bronx, NY       6038
# 4     14000US36005001901      Census Tract 19.01, Bronx, NY       2168
# ...                  ...                                ...        ...
# 2323  14000US36085031901  Census Tract 319.01, Richmond, NY       3422
# 2324  14000US36085031902  Census Tract 319.02, Richmond, NY       5298
# 2325  14000US36085032300     Census Tract 323, Richmond, NY       1105
# 2326  14000US36085990100    Census Tract 9901, Richmond, NY          0
# 2327      16000US3651000                       New York, NY    8736047
#
#       B01003001, Error
# 0                  702
# 1                  563
# 2                  903
# ...

# %% [markdown]
# # Race Table

# %%
race_df = pd.read_csv("./census_data_by_tract/acs2021_5yr_B02001_14000US36047030600/acs2021_5yr_B02001_14000US36047030600.csv")

# %%
race_df
# Out:
#                    geoid                               name  B02001001  \
# 0     14000US36005000100          Census Tract 1, Bronx, NY       6661
# 1     14000US36005000200          Census Tract 2, Bronx, NY       4453
# 2     14000US36005000400          Census Tract 4, Bronx, NY       6000
# 3     14000US36005001600         Census Tract 16, Bronx, NY       6038
# 4     14000US36005001901      Census Tract 19.01, Bronx, NY       2168
# ...                  ...                                ...        ...
# 2323  14000US36085031901  Census Tract 319.01, Richmond, NY       3422
# 2324  14000US36085031902  Census Tract 319.02, Richmond, NY       5298
# 2325  14000US36085032300     Census Tract 323, Richmond, NY       1105
# 2326  14000US36085990100    Census Tract 9901, Richmond, NY          0
# 2327      16000US3651000                       New York, NY    8736047
#
#       B02001001, Error  B02001002  B02001002, Error  B02001003  \
# ...
